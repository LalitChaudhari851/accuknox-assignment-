# %%
import requests
import matplotlib.pyplot as plot
import random

url = "https://jsonplaceholder.typicode.com/users"
response = requests.get(url)
users = response.json()

name = []
scores=[]

for user in users[:5]:
    name.append(user["name"])
    scores.append(random.randint(60,95))

average_scores = sum(scores) / len(scores)
print("Average Score :", average_score)

plt.figure(figsize=(10,6))

plt.bar(names,scores)
plt.xlabel("Students")
plt.ylabel("Scores")
plt.title("Student test score")
plt.savefig("student_scores_bar_chart.png")
plt.show()
# Out:
# Average Score : 75.2
